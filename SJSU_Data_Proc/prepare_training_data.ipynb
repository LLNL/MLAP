# %% [markdown]
# # Import Modules

# %%
import os
import sys
import os.path as path
import glob
import numpy as np
import pandas as pd
import xarray as xr
import pickle
#from matplotlib import pyplot as plt
#plt.style.use('seaborn-white')
from datetime import date, datetime, timedelta
import time
import random
# Out:
# /g/g92/jha3/VirtualEnv/py3_ml_wind/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
from helper_functions import generate_seed, init_random_generator
from helper_functions import get_data_file_names, downsample_data_files
from helper_functions import downsample_grid_indices
from helper_functions import create_df_at_gp

# %% [markdown]
# # Variables to be used for preparing training data

# %%
data_files_location = '/p/lustre1/mirocha2/SJSU_DATA/akochanski/PGnE_climo/dfm'
percent_files_to_use = 5.0         # f1 = what percent of available files to use
percent_grid_points_to_use = 0.005  # f2 = what percent of grid points to use
max_history_to_consider = 10 # n_history in hours
history_interval        = 1
frames_in_file          = 153
label_fields = ['mean_wtd_moisture_1hr', 'mean_wtd_moisture_10hr']
identity_fields = ['latitude', 'longitude']
feature_fields = ['eastward_10m_wind', 'northward_10m_wind',\
                  'air_temperature_2m', \
                  'accumulated_precipitation_amount', \
                  'air_relative_humidity_2m', \
                  'surface_downwelling_shortwave_flux']

# %% [markdown]
# # Generate seed for the random number generator

# %%
seed = generate_seed()
random_state = init_random_generator(seed)

# %% [markdown]
# # Paths, File Names, Downsample Files

# %%
data_files_list = get_data_file_names(data_files_location)
sampled_file_indices, sampled_data_files = downsample_data_files (data_files_list, percent_files_to_use)
# Out:
# Getting the names of data files at the dir :
#  /p/lustre1/mirocha2/SJSU_DATA/akochanski/PGnE_climo/dfm
# Found 99 files
# =========================================================================
#
# Randomly selecting approx 5.0 % of the data files
# Selected 5 data files
# Indices of the randomly selected files
#  [66, 30, 29, 0, 78]
# Names of the randomly selected files
#  ['wrfout_d03_1990-07-23_00:00:00_dfm.nc', 'wrfout_d03_1990-01-24_00:00:00_dfm.nc', 'wrfout_d03_1990-01-19_00:00:00_dfm.nc', 'wrfout_d03_1989-08-04_00:00:00_dfm.nc', 'wrfout_d03_1990-09-21_00:00:00_dfm.nc']
# =========================================================================

# %% [markdown]
# # Grid Dimensions, Downsample Grid Points

# %%
df_combined = pd.DataFrame()
for file_count, data_file_name in enumerate(sampled_data_files):
    print ('\nReading data from file # {}, with name :- {}'.format(file_count, data_file_name))
    dfm_file_data = xr.open_dataset(path.join(data_files_location, data_file_name))
    i_indices, j_indices, sampled_grid_indices = downsample_grid_indices (dfm_file_data, percent_grid_points_to_use)
    #print('i_indices: {}'.format(i_indices))
    #print('j_indices: {}'.format(j_indices))
    #print('sampled_grid_indices: {}'.format(sampled_grid_indices))
    
    for gp_count, (i_ind, j_ind) in enumerate(zip (i_indices, j_indices)):
        print('Grip point # {} : i = {}, j = {}'.format(gp_count, i_ind, j_ind))
        FM_time_index, AtmData_time_indices, df_at_gp = create_df_at_gp (dfm_file_data, i_ind, j_ind, max_history_to_consider, history_interval, frames_in_file)
        #print('DataFrame at grid point: \n {}'.format(df_at_gp))
        #print('... ... ...')
        if (not df_at_gp.isna().values.any()):
            df_combined = df_combined.append(df_at_gp).reset_index(drop = True)
    print('------------------------------------------------------------')
# Out:
# Reading data from file # 0, with name :- wrfout_d03_1990-07-23_00:00:00_dfm.nc
#
# Randomly selecting 0.005 % of the grid points
# Dimensions: 396 X 480, Num of grid points: 190080
# Selected 10 grid points
# Sampled grid indices:
# [12153, 103350, 74430, 5455, 77387, 25973, 106859, 143938, 188695, 181002]
# Sampled i-indices:
# [273 390 378 307 167 233 335 190 199  30]
# Sampled j-indices:
# [ 30 260 187  13 195  65 269 363 476 457]
# Grip point # 0 : i = 273, j = 30
# Grip point # 1 : i = 390, j = 260
# Grip point # 2 : i = 378, j = 187
# Grip point # 3 : i = 307, j = 13
# Grip point # 4 : i = 167, j = 195
# Grip point # 5 : i = 233, j = 65
# Grip point # 6 : i = 335, j = 269
# Grip point # 7 : i = 190, j = 363
# Grip point # 8 : i = 199, j = 476
# Grip point # 9 : i = 30, j = 457
# ------------------------------------------------------------
#
# Reading data from file # 1, with name :- wrfout_d03_1990-01-24_00:00:00_dfm.nc
#
# Randomly selecting 0.005 % of the grid points
# Dimensions: 396 X 480, Num of grid points: 190080
# Selected 10 grid points
# Sampled grid indices:
# [2416, 107693, 103235, 120991, 67106, 154641, 13537, 82704, 67992, 30163]
# Sampled i-indices:
# [ 40 377 275 211 182 201  73 336 276  67]
# Sampled j-indices:
# [  6 271 260 305 169 390  34 208 171  76]
# Grip point # 0 : i = 40, j = 6
# Grip point # 1 : i = 377, j = 271
# Grip point # 2 : i = 275, j = 260
# Grip point # 3 : i = 211, j = 305
# Grip point # 4 : i = 182, j = 169
# Grip point # 5 : i = 201, j = 390
# Grip point # 6 : i = 73, j = 34
# Grip point # 7 : i = 336, j = 208
# Grip point # 8 : i = 276, j = 171
# Grip point # 9 : i = 67, j = 76
# ------------------------------------------------------------
#
# Reading data from file # 2, with name :- wrfout_d03_1990-01-19_00:00:00_dfm.nc
#
# Randomly selecting 0.005 % of the grid points
# Dimensions: 396 X 480, Num of grid points: 190080
# Selected 10 grid points
# Sampled grid indices:
# [47408, 98187, 77298, 28375, 169801, 87474, 141743, 23652, 26568, 173276]
# Sampled i-indices:
# [284 375  78 259 313 354 371 288  36 224]
# Sampled j-indices:
# [119 247 195  71 428 220 357  59  67 437]
# Grip point # 0 : i = 284, j = 119
# Grip point # 1 : i = 375, j = 247
# Grip point # 2 : i = 78, j = 195
# Grip point # 3 : i = 259, j = 71
# Grip point # 4 : i = 313, j = 428
# Grip point # 5 : i = 354, j = 220
# Grip point # 6 : i = 371, j = 357
# Grip point # 7 : i = 288, j = 59
# Grip point # 8 : i = 36, j = 67
# Grip point # 9 : i = 224, j = 437
# ------------------------------------------------------------
#
# Reading data from file # 3, with name :- wrfout_d03_1989-08-04_00:00:00_dfm.nc
#
# Randomly selecting 0.005 % of the grid points
# Dimensions: 396 X 480, Num of grid points: 190080
# Selected 10 grid points
# Sampled grid indices:
# [6773, 86232, 171056, 95614, 148584, 14947, 89297, 167356, 32320, 32789]
# Sampled i-indices:
# [ 41 300 380 178  84 295 197 244 244 317]
# Sampled j-indices:
# [ 17 217 431 241 375  37 225 422  81  82]
# Grip point # 0 : i = 41, j = 17
# Grip point # 1 : i = 300, j = 217
# Grip point # 2 : i = 380, j = 431
# Grip point # 3 : i = 178, j = 241
# Grip point # 4 : i = 84, j = 375
# Grip point # 5 : i = 295, j = 37
# Grip point # 6 : i = 197, j = 225
# Grip point # 7 : i = 244, j = 422
# Grip point # 8 : i = 244, j = 81
# Grip point # 9 : i = 317, j = 82
# ------------------------------------------------------------
#
# Reading data from file # 4, with name :- wrfout_d03_1990-09-21_00:00:00_dfm.nc
#
# Randomly selecting 0.005 % of the grid points
# Dimensions: 396 X 480, Num of grid points: 190080
# Selected 10 grid points
# Sampled grid indices:
# [34965, 149637, 57992, 102007, 49877, 105933, 74314, 185852, 103514, 121194]
# Sampled i-indices:
# [117 345 176 235 377 201 262 128 158  18]
# Sampled j-indices:
# [ 88 377 146 257 125 267 187 469 261 306]
# Grip point # 0 : i = 117, j = 88
# Grip point # 1 : i = 345, j = 377
# Grip point # 2 : i = 176, j = 146
# Grip point # 3 : i = 235, j = 257
# Grip point # 4 : i = 377, j = 125
# Grip point # 5 : i = 201, j = 267
# Grip point # 6 : i = 262, j = 187
# Grip point # 7 : i = 128, j = 469
# Grip point # 8 : i = 158, j = 261
# Grip point # 9 : i = 18, j = 306
# ------------------------------------------------------------

# %%
df_combined.head(10)
# Out:
#          lat         lon   FM_10hr    FM_1hr   U10[-9]   V10[-9]     T2[-9]  \
# 0  38.295979 -116.596176  0.037678  0.043040  1.179513  2.209197  29.042542
# 1  36.984035 -116.948502  0.042490  0.059947 -2.014308  5.684172  20.878113
# 2  37.200932 -121.740021  0.150343  0.149058 -2.128006  1.950207  14.534149
# 3  34.844704 -120.264008  0.163846  0.301983  1.773816 -1.616036  14.135590
# 4  38.500580 -117.858887  0.033154  0.034298  2.027003 -3.133134  24.712311
# 5  40.248459 -121.222443  0.056709  0.054493 -0.638940 -0.209227  15.533661
# 6  42.294544 -121.006622  0.093149  0.142444  3.264637 -2.464468  19.136047
# 7  38.506275 -116.884674  0.070429  0.082326 -1.444979 -2.081428   0.155518
# 8  38.367168 -119.252914  0.259043  0.843899  5.082563 -3.119682  -2.600372
# 9  39.196712 -120.729080  0.121286  0.071809 -3.161840 -0.540487   0.159760
#
#    Precip[-9]   RH2[-9]     SDSF[-9]  ...     T2[-2]  Precip[-2]   RH2[-2]  \
# 0    0.000000  0.093996  1014.491333  ...  23.746796    0.000000  0.123198
# 1    0.000000  0.166365     0.000000  ...  18.969330    0.000000  0.232457
# 2    0.000000  0.814076     0.000000  ...  14.963348    0.000000  0.769306
# 3    0.000066  0.918450     0.000000  ...  12.691681    0.000109  0.991602
# 4    0.000000  0.151060   792.799805  ...  28.550049    0.000000  0.104091
# 5    0.000000  0.519774   351.784637  ...  23.104462    0.000000  0.211342
# 6    0.000000  0.269744   792.157959  ...  12.378326    0.000000  0.588358
# 7    0.000000  0.211907   473.651367  ...  -1.690094    0.000000  0.250153
# 8    0.000000  0.189301     0.000000  ...  -2.971466    0.000000  0.227623
# 9    0.059895  0.488645     0.000000  ...   9.691711    0.059895  0.213349
#
#      SDSF[-2]   U10[-1]   V10[-1]     T2[-1]  Precip[-1]   RH2[-1]    SDSF[-1]
# 0    0.000000  2.530737 -2.018502  22.592316    0.000000  0.126817    0.000000
# 1  205.058151 -1.279327 -0.675308  20.776825    0.000000  0.225292  425.853699
# 2  284.336670 -4.697626  2.985459  16.607330    0.000000  0.694228  519.356018
# 3    0.000000  1.031104 -0.959487  12.441498    0.000113  0.991782    0.000000
# 4  594.679199  0.835772  0.412687  28.106293    0.000000  0.111033  384.034729
# 5  935.859863  4.230122 -0.121537  23.354248    0.000000  0.220706  804.925537
# 6    0.000000  1.527022 -1.589275  11.184021    0.000000  0.646677    0.000000
# 7    0.000000 -0.797542  0.997377  -1.231506    0.000000  0.248202    0.000000
# 8    0.000000  8.596319 -1.004557  -1.552399    0.000000  0.212761    0.000000
# 9  556.642090  1.331005  1.107436  10.770264    0.059895  0.203431  602.742859
#
# [10 rows x 58 columns]

# %% [markdown]
# # Save the training data

# %%
training_data_file_name = 'training_data_files_{}pc_grid_points_{}pc_max_history_{}_hist_interval_{}'.format(
                            percent_files_to_use, # f1 = what percent of available files to use
                            percent_grid_points_to_use, # f2 = what percent of grid points to use
                            max_history_to_consider, # n_history in hours
                            history_interval)
training_data = {'percent_files_to_use': percent_files_to_use,
                 'percent_grid_points_to_use': percent_grid_points_to_use,
                 'max_history_to_consider': max_history_to_consider,
                 'history_interval': history_interval,
                 'df_combined': df_combined}
training_data_file_handle = open(training_data_file_name, 'wb')
pickle.dump(training_data, training_data_file_handle)

# %%
pickle.dump(training_data, training_data_file_handle)
training_data_file_handle.close()

# %%
loaded_data = pickle.load(open(training_data_file_name, 'rb'))

# %%
loaded_data['df_combined']
# Out:
#           lat         lon   FM_10hr    FM_1hr   U10[-9]   V10[-9]     T2[-9]  \
# 0   38.295979 -116.596176  0.037678  0.043040  1.179513  2.209197  29.042542
# 1   36.984035 -116.948502  0.042490  0.059947 -2.014308  5.684172  20.878113
# 2   37.200932 -121.740021  0.150343  0.149058 -2.128006  1.950207  14.534149
# 3   34.844704 -120.264008  0.163846  0.301983  1.773816 -1.616036  14.135590
# 4   38.500580 -117.858887  0.033154  0.034298  2.027003 -3.133134  24.712311
# 5   40.248459 -121.222443  0.056709  0.054493 -0.638940 -0.209227  15.533661
# 6   42.294544 -121.006622  0.093149  0.142444  3.264637 -2.464468  19.136047
# 7   38.506275 -116.884674  0.070429  0.082326 -1.444979 -2.081428   0.155518
# 8   38.367168 -119.252914  0.259043  0.843899  5.082563 -3.119682  -2.600372
# 9   39.196712 -120.729080  0.121286  0.071809 -3.161840 -0.540487   0.159760
# 10  36.731075 -121.396606  0.159104  0.208972  0.934618 -2.020010  11.277252
# 11  40.737682 -120.960449  0.430405  0.842002  2.073486  1.434015  -1.943359
# 12  37.394604 -117.884583  0.070081  0.063848  2.520775  1.000675  -0.009125
# 13  36.753555 -119.270081  0.115294  0.118466  0.673836  1.669022   4.495117
# 14  35.808517 -119.114166  0.115290  0.140787  0.947341 -1.292288  13.554810
# 15  38.073177 -116.955780  0.104752  0.086922 -2.026925  0.389742  -7.907562
# 16  34.947678 -119.688690  0.146630  0.189758 -0.949936  2.435043   5.776611
# 17  41.393578 -118.255814  0.124394  0.153760  0.384217 -0.603470  -3.128662
# 18  37.599998 -117.463425  0.151823  0.221562 -0.526512 -0.118884  -8.237885
# 19  40.068668 -116.934204  0.106372  0.101831 -0.143326  2.632820  -3.640869
# 20  34.720825 -119.054214  0.137801  0.164318 -0.466285  0.697582  -0.015503
# 21  41.587013 -120.402328  0.108456  0.112142  0.679105  0.382409  -4.059814
# 22  37.577385 -118.700546  0.155428  0.123998  0.215994 -0.881344  13.650208
# 23  41.400166 -116.637115  0.091635  0.083495 -2.482344 -2.086716  14.793671
# 24  38.036076 -121.494370  0.090418  0.135650  4.458466 -0.604470  30.402679
# 25  40.436710 -123.746643  0.099361  0.099743 -1.772404 -2.253342  19.350494
# 26  34.320000 -118.911499  0.149455  0.168039 -0.549245  1.554748  18.938538
# 27  37.746708 -121.057068  0.099093  0.084533  0.912552 -2.403073  17.999512
# 28  41.311859 -119.922867  0.130617  0.085801  0.162662  1.226279  14.233856
# 29  35.132309 -120.017365  0.108616  0.097101  4.811162  1.503177  20.519806
# 30  35.123650 -118.401306  0.056150  0.066606  4.004862 -1.665692  29.971405
# 31  40.450390 -117.531311  0.221855  0.849991 -4.619448  1.733310  14.165405
# 32  36.313786 -121.529770  0.071660  0.077451 -2.001994  2.538290  11.425537
# 33  38.323479 -120.178604  0.620408  0.950000 -0.307033  1.169138  17.360260
# 34  35.862370 -117.032776  0.078191  0.094859 -0.473621 -7.600427  15.742462
# 35  38.508183 -120.964142  0.189160  0.092966 -4.499032 -2.909733  17.494385
# 36  37.048077 -119.580902  0.084262  0.072699 -1.578842  3.581761  15.140076
# 37  42.156902 -122.739502  0.229007  0.235878  2.548021  1.779854  12.840332
# 38  38.396168 -121.959137  0.105023  0.093683  0.424467 -0.607188  17.326202
#
#     Precip[-9]   RH2[-9]     SDSF[-9]  ...     T2[-2]  Precip[-2]   RH2[-2]  \
# 0     0.000000  0.093996  1014.491333  ...  23.746796    0.000000  0.123198
# 1     0.000000  0.166365     0.000000  ...  18.969330    0.000000  0.232457
# 2     0.000000  0.814076     0.000000  ...  14.963348    0.000000  0.769306
# 3     0.000066  0.918450     0.000000  ...  12.691681    0.000109  0.991602
# 4     0.000000  0.151060   792.799805  ...  28.550049    0.000000  0.104091
# 5     0.000000  0.519774   351.784637  ...  23.104462    0.000000  0.211342
# 6     0.000000  0.269744   792.157959  ...  12.378326    0.000000  0.588358
# 7     0.000000  0.211907   473.651367  ...  -1.690094    0.000000  0.250153
# 8     0.000000  0.189301     0.000000  ...  -2.971466    0.000000  0.227623
# 9     0.059895  0.488645     0.000000  ...   9.691711    0.059895  0.213349
# 10    0.001100  0.644981   601.016113  ...   8.498840    0.001214  0.820876
# 11    0.000000  0.434304     0.000000  ...  -3.673889    0.000000  0.421509
# 12    0.000000  0.285875     0.000000  ...   7.122223    0.000000  0.185124
# 13    0.000000  0.740140     0.000000  ...   9.655701    0.000000  0.553405
# 14    0.000000  0.345827   385.957733  ...   7.745270    0.000000  0.578506
# 15    0.000000  0.437289     0.000000  ...  -2.409119    0.000000  0.226460
# 16    0.000000  0.633197     0.000000  ...   2.690216    0.000000  0.721490
# 17    0.000000  0.569395     0.000000  ...  -2.942902    0.000000  0.566422
# 18    0.000000  0.574153     0.000000  ...  -4.727905    0.000000  0.376722
# 19    0.000000  0.358309   312.406006  ...   0.339661    0.000000  0.314571
# 20    0.000000  0.527903     0.000000  ...  -2.478333    0.000000  0.648778
# 21    0.000000  0.587379     0.000000  ...  -1.073975    0.000000  0.417386
# 22    0.466552  1.000000     0.000000  ...  18.706909    0.466552  0.637921
# 23    0.000000  0.444855     0.000000  ...  16.364471    0.000000  0.399256
# 24    0.000000  0.257864   130.854111  ...  18.614227    0.000000  0.586237
# 25    0.000000  0.575068     0.000000  ...  19.947571    0.000000  0.454391
# 26    0.000000  0.691932     0.000000  ...  18.771698    0.000000  0.721583
# 27    0.026597  0.618825     0.000000  ...  22.332062    0.026597  0.449795
# 28    0.516329  0.580620     0.000000  ...  19.517181    0.516329  0.469569
# 29    0.000000  0.341168     0.000000  ...  17.302521    0.000000  0.410709
# 30    0.000000  0.125708   929.189697  ...  21.800049    0.000000  0.227779
# 31    0.012676  0.405516   228.464935  ...  22.361206    0.021684  0.249242
# 32    0.000000  0.734762     0.000000  ...  23.012848    0.000000  0.354751
# 33    0.006756  0.358249   735.475037  ...  11.106445    1.827844  0.834951
# 34    0.112105  0.546692     0.000000  ...  19.654419    0.112275  0.479710
# 35    0.531526  0.751879     0.000000  ...  23.797058    0.531526  0.498572
# 36    0.383581  0.775298     5.972084  ...  25.823578    0.383581  0.351299
# 37    0.016295  0.849897     0.000000  ...   9.601105    0.016389  1.000000
# 38    0.054739  0.624235     0.000000  ...  22.798340    0.054739  0.470610
#
#       SDSF[-2]   U10[-1]   V10[-1]     T2[-1]  Precip[-1]   RH2[-1]  \
# 0     0.000000  2.530737 -2.018502  22.592316    0.000000  0.126817
# 1   205.058151 -1.279327 -0.675308  20.776825    0.000000  0.225292
# 2   284.336670 -4.697626  2.985459  16.607330    0.000000  0.694228
# 3     0.000000  1.031104 -0.959487  12.441498    0.000113  0.991782
# 4   594.679199  0.835772  0.412687  28.106293    0.000000  0.111033
# 5   935.859863  4.230122 -0.121537  23.354248    0.000000  0.220706
# 6     0.000000  1.527022 -1.589275  11.184021    0.000000  0.646677
# 7     0.000000 -0.797542  0.997377  -1.231506    0.000000  0.248202
# 8     0.000000  8.596319 -1.004557  -1.552399    0.000000  0.212761
# 9   556.642090  1.331005  1.107436  10.770264    0.059895  0.203431
# 10    0.000000  1.515761 -0.733264   8.119598    0.001215  0.833694
# 11    0.000000  1.843602  1.971328  -2.939728    0.000000  0.402579
# 12  484.836853  0.372040  4.311204   6.955261    0.000000  0.177734
# 13  613.540039 -0.165143  1.665391  10.028564    0.000000  0.521346
# 14    0.000000 -2.123994  0.870290   6.998810    0.000000  0.594165
# 15  499.404816  0.809808  1.251832   1.007507    0.000000  0.166489
# 16    0.000000 -2.044210  1.277462   2.208221    0.000000  0.759446
# 17    0.000000 -0.401418 -0.015989  -3.638214    0.000000  0.603261
# 18  517.328796  0.508074  0.573476  -3.160950    0.000000  0.310381
# 19  122.540230 -1.368868 -3.475718  -2.698853    0.000000  0.428680
# 20    0.000000  0.651186 -0.580226  -2.626892    0.000000  0.654474
# 21  398.057220 -0.041773 -2.005007  -0.541565    0.000000  0.375984
# 22  716.930908 -4.421498  2.038179  20.072083    0.466552  0.582523
# 23  399.980011  0.720691 -0.781214  18.633545    0.000000  0.346251
# 24    0.000000  0.047048 -0.850308  17.706940    0.000000  0.643454
# 25    0.000000 -2.617341  2.050846  19.621582    0.000000  0.408345
# 26    0.000000 -0.052908  0.030944  17.986481    0.000000  0.754595
# 27  496.132721  2.287974 -2.678860  25.025665    0.026597  0.379890
# 28  824.441711  3.147748  4.673162  20.713135    0.516329  0.407172
# 29    0.000000  3.377692  2.401222  16.916840    0.000000  0.401962
# 30    0.000000  4.043473 -0.810100  20.479645    0.000000  0.258231
# 31  657.566162 -3.733257  7.203300  21.659790    0.027219  0.277979
# 32  777.133606 -3.030183  1.525625  23.539795    0.000000  0.367151
# 33   12.727938  0.028183  0.216019  10.714905    1.903342  0.860362
# 34  458.651947 -4.659372 -6.816573  20.563263    0.112275  0.454203
# 35  686.712769  2.213394 -0.690354  25.635620    0.531526  0.425902
# 36  791.846375  2.498357  0.685633  26.270569    0.383581  0.328652
# 37    0.000000 -0.026500  1.623663  10.912354    0.016389  0.842622
# 38  670.375183 -0.010147 -0.062254  23.245697    0.054739  0.449219
#
#       SDSF[-1]
# 0     0.000000
# 1   425.853699
# 2   519.356018
# 3     0.000000
# 4   384.034729
# 5   804.925537
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9   602.742859
# 10    0.000000
# 11    0.000000
# 12  322.696045
# 13  532.938965
# 14    0.000000
# 15  592.797302
# 16    0.000000
# 17    0.000000
# 18  618.221130
# 19    0.000000
# 20    0.000000
# 21  498.173401
# 22  864.798401
# 23  599.496765
# 24    0.000000
# 25    0.000000
# 26    0.000000
# 27  682.069214
# 28  923.230286
# 29    0.000000
# 30    0.000000
# 31  447.922241
# 32  722.147461
# 33    0.000000
# 34  643.036133
# 35  743.279175
# 36  688.070007
# 37    0.000000
# 38  751.626892
#
# [39 rows x 58 columns]
