# %% [markdown]
# # Import Modules

# %%
import os
import sys
import os.path as path
import glob
import numpy as np
import pandas as pd
import xarray as xr
import pickle
#from matplotlib import pyplot as plt
#plt.style.use('seaborn-white')
from datetime import date, datetime, timedelta
import time
import random
# Out:
# /g/g92/jha3/VirtualEnv/py3_ml_wind/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
from helper_functions import generate_seed, init_random_generator
from helper_functions import get_data_file_names, downsample_data_files
from helper_functions import downsample_grid_indices
from helper_functions import create_df_at_gp

# %% [markdown]
# # Variables to be used for preparing training data

# %%
data_files_location = '/p/lustre1/mirocha2/SJSU_DATA/akochanski/PGnE_climo/dfm'
percent_files_to_use = 50.0         # f1 = what percent of available files to use
percent_grid_points_to_use = 0.005  # f2 = what percent of grid points to use
max_history_to_consider = 5 # n_history in hours
history_interval        = 2
frames_in_file          = 153
label_fields = ['mean_wtd_moisture_1hr', 'mean_wtd_moisture_10hr']
identity_fields = ['latitude', 'longitude']
feature_fields = ['eastward_10m_wind', 'northward_10m_wind',\
                  'air_temperature_2m', \
                  'accumulated_precipitation_amount', \
                  'air_relative_humidity_2m', \
                  'surface_downwelling_shortwave_flux']

# %% [markdown]
# # Generate seed for the random number generator

# %%
seed = generate_seed()
random_state = init_random_generator(seed)

# %% [markdown]
# # Paths, File Names, Downsample Files

# %%
data_files_list = get_data_file_names(data_files_location)
sampled_file_indices, sampled_data_files = downsample_data_files (data_files_list, percent_files_to_use)
# Out:
# Getting the names of data files at the dir :
#  /p/lustre1/mirocha2/SJSU_DATA/akochanski/PGnE_climo/dfm
# Found 99 files
# =========================================================================
#
# Randomly selecting approx 50.0 % of the data files
# Selected 50 data files
# Indices of the randomly selected files:
#  [45, 51, 1, 72, 66, 10, 90, 47, 70, 56, 85, 23, 93, 7, 28, 76, 8, 19, 33, 4, 5, 46, 53, 25, 92, 59, 15, 74, 18, 86, 69, 98, 71, 73, 57, 78, 11, 62, 31, 29, 37, 40, 60, 61, 16, 48, 9, 12, 77, 65]
# Names of the randomly selected files:
#  ['wrfout_d03_1990-04-09_00:00:00_dfm.nc', 'wrfout_d03_1990-05-09_00:00:00_dfm.nc', 'wrfout_d03_1989-09-01_00:00:00_dfm.nc', 'wrfout_d03_1990-08-22_00:00:00_dfm.nc', 'wrfout_d03_1990-07-23_00:00:00_dfm.nc', 'wrfout_d03_1989-10-16_00:00:00_dfm.nc', 'wrfout_d03_1990-11-20_00:00:00_dfm.nc', 'wrfout_d03_1990-04-19_00:00:00_dfm.nc', 'wrfout_d03_1990-08-12_00:00:00_dfm.nc', 'wrfout_d03_1990-06-03_00:00:00_dfm.nc', 'wrfout_d03_1990-10-26_00:00:00_dfm.nc', 'wrfout_d03_1989-12-20_00:00:00_dfm.nc', 'wrfout_d03_1990-12-05_00:00:00_dfm.nc', 'wrfout_d03_1989-10-01_00:00:00_dfm.nc', 'wrfout_d03_1990-01-14_00:00:00_dfm.nc', 'wrfout_d03_1990-09-11_00:00:00_dfm.nc', 'wrfout_d03_1989-10-06_00:00:00_dfm.nc', 'wrfout_d03_1989-11-30_00:00:00_dfm.nc', 'wrfout_d03_1990-02-08_00:00:00_dfm.nc', 'wrfout_d03_1989-09-16_00:00:00_dfm.nc', 'wrfout_d03_1989-09-21_00:00:00_dfm.nc', 'wrfout_d03_1990-04-14_00:00:00_dfm.nc', 'wrfout_d03_1990-05-19_00:00:00_dfm.nc', 'wrfout_d03_1989-12-30_00:00:00_dfm.nc', 'wrfout_d03_1990-11-30_00:00:00_dfm.nc', 'wrfout_d03_1990-06-18_00:00:00_dfm.nc', 'wrfout_d03_1989-11-10_00:00:00_dfm.nc', 'wrfout_d03_1990-09-01_00:00:00_dfm.nc', 'wrfout_d03_1989-11-25_00:00:00_dfm.nc', 'wrfout_d03_1990-10-31_00:00:00_dfm.nc', 'wrfout_d03_1990-08-07_00:00:00_dfm.nc', 'wrfout_d03_1990-12-30_00:00:00_dfm.nc', 'wrfout_d03_1990-08-17_00:00:00_dfm.nc', 'wrfout_d03_1990-08-27_00:00:00_dfm.nc', 'wrfout_d03_1990-06-08_00:00:00_dfm.nc', 'wrfout_d03_1990-09-21_00:00:00_dfm.nc', 'wrfout_d03_1989-10-21_00:00:00_dfm.nc', 'wrfout_d03_1990-07-03_00:00:00_dfm.nc', 'wrfout_d03_1990-01-29_00:00:00_dfm.nc', 'wrfout_d03_1990-01-19_00:00:00_dfm.nc', 'wrfout_d03_1990-02-28_00:00:00_dfm.nc', 'wrfout_d03_1990-03-15_00:00:00_dfm.nc', 'wrfout_d03_1990-06-23_00:00:00_dfm.nc', 'wrfout_d03_1990-06-28_00:00:00_dfm.nc', 'wrfout_d03_1989-11-15_00:00:00_dfm.nc', 'wrfout_d03_1990-04-24_00:00:00_dfm.nc', 'wrfout_d03_1989-10-11_00:00:00_dfm.nc', 'wrfout_d03_1989-10-26_00:00:00_dfm.nc', 'wrfout_d03_1990-09-16_00:00:00_dfm.nc', 'wrfout_d03_1990-07-18_00:00:00_dfm.nc']
# =========================================================================

# %% [markdown]
# # Grid Dimensions, Downsample Grid Points

# %%
df_for_all_files = pd.DataFrame()
for file_count, data_file_name in enumerate(sampled_data_files):
    print ('\nReading data from file # {}, with name :- {}'.format(file_count, data_file_name))
    print('-----------------------------------------------------------------------')
    dfm_file_data = xr.open_dataset(path.join(data_files_location, data_file_name))
    
    df_for_single_file = downsample_grid_indices (dfm_file_data, percent_grid_points_to_use, 
                                                  max_history_to_consider, history_interval, frames_in_file)
    
    df_for_all_files = df_for_all_files.append(df_for_single_file).reset_index(drop = True)
# Out:
# Reading data from file # 0, with name :- wrfout_d03_1990-04-09_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 1, with name :- wrfout_d03_1990-05-09_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 2, with name :- wrfout_d03_1989-09-01_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 3, with name :- wrfout_d03_1990-08-22_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 4, with name :- wrfout_d03_1990-07-23_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 5, with name :- wrfout_d03_1989-10-16_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 6, with name :- wrfout_d03_1990-11-20_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 7, with name :- wrfout_d03_1990-04-19_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 8, with name :- wrfout_d03_1990-08-12_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 9, with name :- wrfout_d03_1990-06-03_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 10, with name :- wrfout_d03_1990-10-26_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 11, with name :- wrfout_d03_1989-12-20_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 12, with name :- wrfout_d03_1990-12-05_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 13, with name :- wrfout_d03_1989-10-01_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 14, with name :- wrfout_d03_1990-01-14_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 15, with name :- wrfout_d03_1990-09-11_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 16, with name :- wrfout_d03_1989-10-06_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 17, with name :- wrfout_d03_1989-11-30_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 18, with name :- wrfout_d03_1990-02-08_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 19, with name :- wrfout_d03_1989-09-16_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 20, with name :- wrfout_d03_1989-09-21_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 21, with name :- wrfout_d03_1990-04-14_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 22, with name :- wrfout_d03_1990-05-19_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 23, with name :- wrfout_d03_1989-12-30_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 24, with name :- wrfout_d03_1990-11-30_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 25, with name :- wrfout_d03_1990-06-18_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 26, with name :- wrfout_d03_1989-11-10_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 27, with name :- wrfout_d03_1990-09-01_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 28, with name :- wrfout_d03_1989-11-25_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 29, with name :- wrfout_d03_1990-10-31_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 30, with name :- wrfout_d03_1990-08-07_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 31, with name :- wrfout_d03_1990-12-30_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 32, with name :- wrfout_d03_1990-08-17_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 33, with name :- wrfout_d03_1990-08-27_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 34, with name :- wrfout_d03_1990-06-08_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 35, with name :- wrfout_d03_1990-09-21_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 36, with name :- wrfout_d03_1989-10-21_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 37, with name :- wrfout_d03_1990-07-03_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 38, with name :- wrfout_d03_1990-01-29_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 39, with name :- wrfout_d03_1990-01-19_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 40, with name :- wrfout_d03_1990-02-28_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 41, with name :- wrfout_d03_1990-03-15_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 42, with name :- wrfout_d03_1990-06-23_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 43, with name :- wrfout_d03_1990-06-28_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 44, with name :- wrfout_d03_1989-11-15_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 45, with name :- wrfout_d03_1990-04-24_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 46, with name :- wrfout_d03_1989-10-11_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 47, with name :- wrfout_d03_1989-10-26_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 48, with name :- wrfout_d03_1990-09-16_00:00:00_dfm.nc
# -----------------------------------------------------------------------
#
# Reading data from file # 49, with name :- wrfout_d03_1990-07-18_00:00:00_dfm.nc
# -----------------------------------------------------------------------

# %%
df_for_all_files.head(10)
# Out:
#          lat         lon   FM_10hr    FM_1hr   U10[-4]   V10[-4]     T2[-4]  \
# 0  41.705215 -117.078568  0.119069  0.142763  0.920528 -0.460592   5.718597
# 1  42.184338 -123.301788  0.146209  0.175756  1.354522  0.919016   7.145874
# 2  41.909821 -122.174225  0.114832  0.150049 -0.096242  3.746594   9.993744
# 3  39.434334 -118.192505  0.095024  0.079315 -1.374921 -2.958729  15.483276
# 4  40.600117 -122.702667  0.098316  0.109041  2.041034  0.641563   7.242401
# 5  41.754669 -123.020996  0.107141  0.141260 -0.057670  0.608179  14.108887
# 6  36.558159 -119.545654  0.094246  0.102968  1.818960  0.611185  14.256897
# 7  41.348297 -122.213593  0.366856  0.849947  2.067078 -1.117344   0.504364
# 8  39.577171 -116.397736  0.119322  0.145762 -0.318048 -0.258749  -0.689423
# 9  38.435047 -118.973358  0.052226  0.047166 -0.951465 -0.288855  22.105011
#
#    Precip[-4]   RH2[-4]    SDSF[-4]   U10[-2]   V10[-2]     T2[-2]  \
# 0    0.000100  0.596931    0.000000 -0.049356  1.451619   4.868042
# 1    0.000000  0.846082    0.000000  0.876572  0.220149   6.748352
# 2    0.000000  0.579384    0.000000 -0.670532  3.467349   9.936157
# 3    0.005500  0.216658   34.243313  0.718075 -2.464024  12.708557
# 4    0.000027  0.447608    0.000000  2.236888  0.569929   6.916107
# 5    0.000000  0.591198    0.000000 -0.249225  1.413580  13.737274
# 6    0.000000  0.673592  241.920319  0.588389  0.076570  18.442291
# 7    0.000000  0.622075    0.000000  1.835740 -0.859852   1.952698
# 8    0.000000  0.811283    0.000000  0.299222 -0.297270   0.637024
# 9    0.000000  0.152896  895.251038  3.930423  2.396085  22.686859
#
#    Precip[-2]   RH2[-2]    SDSF[-2]
# 0    0.000100  0.615500    0.000000
# 1    0.000000  0.877705   32.738674
# 2    0.000000  0.601483    0.000000
# 3    0.005500  0.261151    0.000000
# 4    0.000027  0.372894    0.000000
# 5    0.000000  0.605511    0.000000
# 6    0.000000  0.538737  637.195862
# 7    0.000000  0.523121  191.538284
# 8    0.000000  0.759536  324.473907
# 9    0.000000  0.141999  697.917297

# %% [markdown]
# # Save the training data

# %%
training_data_file_name = 'training_data_files_{}pc_grid_points_{}pc_max_history_{}_hist_interval_{}'.format(
                            percent_files_to_use, # f1 = what percent of available files to use
                            percent_grid_points_to_use, # f2 = what percent of grid points to use
                            max_history_to_consider, # n_history in hours
                            history_interval)
training_data = {'percent_files_to_use': percent_files_to_use,
                 'percent_grid_points_to_use': percent_grid_points_to_use,
                 'max_history_to_consider': max_history_to_consider,
                 'history_interval': history_interval,
                 'df_for_all_files': df_for_all_files}
training_data_file_handle = open(training_data_file_name, 'wb')
pickle.dump(training_data, training_data_file_handle)
training_data_file_handle.close()

# %% [markdown]
# # Load training data from pickle file

# %%
loaded_data = pickle.load(open(training_data_file_name, 'rb'))

# %%
loaded_data['df_for_all_files'].head(10)
# Out:
#          lat         lon   FM_10hr    FM_1hr   U10[-4]   V10[-4]     T2[-4]  \
# 0  41.705215 -117.078568  0.119069  0.142763  0.920528 -0.460592   5.718597
# 1  42.184338 -123.301788  0.146209  0.175756  1.354522  0.919016   7.145874
# 2  41.909821 -122.174225  0.114832  0.150049 -0.096242  3.746594   9.993744
# 3  39.434334 -118.192505  0.095024  0.079315 -1.374921 -2.958729  15.483276
# 4  40.600117 -122.702667  0.098316  0.109041  2.041034  0.641563   7.242401
# 5  41.754669 -123.020996  0.107141  0.141260 -0.057670  0.608179  14.108887
# 6  36.558159 -119.545654  0.094246  0.102968  1.818960  0.611185  14.256897
# 7  41.348297 -122.213593  0.366856  0.849947  2.067078 -1.117344   0.504364
# 8  39.577171 -116.397736  0.119322  0.145762 -0.318048 -0.258749  -0.689423
# 9  38.435047 -118.973358  0.052226  0.047166 -0.951465 -0.288855  22.105011
#
#    Precip[-4]   RH2[-4]    SDSF[-4]   U10[-2]   V10[-2]     T2[-2]  \
# 0    0.000100  0.596931    0.000000 -0.049356  1.451619   4.868042
# 1    0.000000  0.846082    0.000000  0.876572  0.220149   6.748352
# 2    0.000000  0.579384    0.000000 -0.670532  3.467349   9.936157
# 3    0.005500  0.216658   34.243313  0.718075 -2.464024  12.708557
# 4    0.000027  0.447608    0.000000  2.236888  0.569929   6.916107
# 5    0.000000  0.591198    0.000000 -0.249225  1.413580  13.737274
# 6    0.000000  0.673592  241.920319  0.588389  0.076570  18.442291
# 7    0.000000  0.622075    0.000000  1.835740 -0.859852   1.952698
# 8    0.000000  0.811283    0.000000  0.299222 -0.297270   0.637024
# 9    0.000000  0.152896  895.251038  3.930423  2.396085  22.686859
#
#    Precip[-2]   RH2[-2]    SDSF[-2]
# 0    0.000100  0.615500    0.000000
# 1    0.000000  0.877705   32.738674
# 2    0.000000  0.601483    0.000000
# 3    0.005500  0.261151    0.000000
# 4    0.000027  0.372894    0.000000
# 5    0.000000  0.605511    0.000000
# 6    0.000000  0.538737  637.195862
# 7    0.000000  0.523121  191.538284
# 8    0.000000  0.759536  324.473907
# 9    0.000000  0.141999  697.917297
